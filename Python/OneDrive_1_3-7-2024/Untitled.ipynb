# %%
import pandas as pd
df=pd.read_csv('Casos_positivos_de_COVID-19-Cund-Boy.csv', sep=';')
df.head()
# Out:
#    id_case  id_municipality name_municipality  id_department name_department  \
# 0   489982               25      CUNDINAMARCA          25899       ZIPAQUIRA
# 1  5932109               25      CUNDINAMARCA          25758            SOPO
# 2  3036330               25      CUNDINAMARCA          25099          BOJACA
# 3  1788659               25      CUNDINAMARCA          25151         CAQUEZA
# 4  4715565               25      CUNDINAMARCA          25290      FUSAGASUGA
#
#    age gender type_contagion      status date_symptom date_death  \
# 0   22      F    Comunitaria  Recuperado    2/08/2020        NaN
# 1   50      M    Comunitaria  Recuperado   18/01/2022        NaN
# 2   67      M    Comunitaria  Recuperado    4/05/2021        NaN
# 3   51      F    Relacionado  Recuperado    4/01/2021        NaN
# 4   40      M    Comunitaria  Recuperado    8/07/2021        NaN
#
#   date_diagnosis date_recovery
# 0     18/08/2020    20/12/2020
# 1      2/02/2022     5/02/2022
# ...
